# %%
pip install ultralytics opencv-python
# Out:
# ...
#
# ...
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from ultralytics import YOLO

# Load the shared model
model = YOLO("best.pt")

# %%
results = model("images/8.jpg", save=True)
results[0].show()
# Out:
# image 1/1 N:\Final Project\images\8.jpg: 640x576 1 guns, 97.8ms
# Speed: 7.5ms preprocess, 97.8ms inference, 10.9ms postprocess per image at shape (1, 3, 640, 576)
# Results saved to N:\Final Project\runs\detect\predict3

# %%
results = model("images/2.mp4", save=True)
# Out:
# WARNING
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/282) N:\Final Project\images\2.mp4: 384x640 (no detections), 84.1ms
# video 1/1 (frame 2/282) N:\Final Project\images\2.mp4: 384x640 (no detections), 75.9ms
# video 1/1 (frame 3/282) N:\Final Project\images\2.mp4: 384x640 (no detections), 71.3ms
# video 1/1 (frame 4/282) N:\Final Project\images\2.mp4: 384x640 (no detections), 72.7ms
# ...
